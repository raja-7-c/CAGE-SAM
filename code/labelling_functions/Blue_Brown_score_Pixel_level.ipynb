# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

def compute_brown_score(image_patch, brown_range):
    total_pixels = np.count_nonzero(np.any(image_patch != [0, 0, 0], axis=-1))
    brown_pixels = np.count_nonzero(
        (image_patch[:, :, 0] >= brown_range[0]) &
        (image_patch[:, :, 0] <= brown_range[1]) &
        (image_patch[:, :, 1] >= brown_range[2]) &
        (image_patch[:, :, 1] <= brown_range[3]) &
        (image_patch[:, :, 2] >= brown_range[4]) &
        (image_patch[:, :, 2] <= brown_range[5])
    )
    brown_score = brown_pixels / total_pixels
    return brown_score


def plot_brown_score_distribution(image_folder, brown_range):
    brown_scores = []

    for filename in os.listdir(image_folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Filter for image files
            image_path = os.path.join(image_folder, filename)
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            image = cv2.resize(image, (30, 30))  # Resize the image to 30x30
            
            # Calculate brown score
            brown_score = compute_brown_score(image, brown_range) 
            brown_scores.append(brown_score)

    plt.hist(brown_scores, bins=20)
    plt.xlabel("Brown Score")
    plt.ylabel("Frequency")
    plt.title("Distribution of Brown Scores Lymphocytes")
    plt.show()


# Example usage:
image_folder = "/content/drive/MyDrive/sam/Train3/Lymphocytes"  # Specify the folder containing the images
brown_range = [0, 80, 20, 150, 40, 120]  # Example brown color range in RGB channels

plot_brown_score_distribution(image_folder, brown_range)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

def compute_brown_score(image_patch, brown_range):
    total_pixels = np.count_nonzero(np.any(image_patch != [0, 0, 0], axis=-1))
    brown_pixels = np.count_nonzero(
        (image_patch[:, :, 0] >= brown_range[0]) &
        (image_patch[:, :, 0] <= brown_range[1]) &
        (image_patch[:, :, 1] >= brown_range[2]) &
        (image_patch[:, :, 1] <= brown_range[3]) &
        (image_patch[:, :, 2] >= brown_range[4]) &
        (image_patch[:, :, 2] <= brown_range[5])
    )
    brown_score = brown_pixels / total_pixels
    return brown_score


def plot_brown_score_distribution(image_folder, brown_range):
    brown_scores = []

    for filename in os.listdir(image_folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Filter for image files
            image_path = os.path.join(image_folder, filename)
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            image = cv2.resize(image, (30, 30))  # Resize the image to 30x30
            
            # Calculate brown score
            brown_score = compute_brown_score(image, brown_range) 
            brown_scores.append(brown_score)

    plt.hist(brown_scores, bins=20)
    plt.xlabel("Brown Score")
    plt.ylabel("Frequency")
    plt.title("Distribution of Brown Scores Non-Lymphocytes")
    plt.show()


# Example usage:
image_folder = "/content/drive/MyDrive/sam/Train3/Non-Lymphocytes"  # Specify the folder containing the images
brown_range = [0, 80, 20, 150, 40, 120]  # Example brown color range in RGB channels

plot_brown_score_distribution(image_folder, brown_range)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

def compute_blue_score(image_patch, blue_range):
    total_pixels = np.count_nonzero(np.any(image_patch != [0, 0, 0], axis=-1))
    blue_pixels = np.count_nonzero(
        (image_patch[:, :, 0] >= blue_range[0]) &
        (image_patch[:, :, 0] <= blue_range[1]) &
        (image_patch[:, :, 1] >= blue_range[2]) &
        (image_patch[:, :, 1] <= blue_range[3]) &
        (image_patch[:, :, 2] >= blue_range[4]) &
        (image_patch[:, :, 2] <= blue_range[5])
    )
    blue_score = blue_pixels
    return blue_score


def plot_blue_score_distribution(image_folder, blue_range):
    blue_scores = []

    for filename in os.listdir(image_folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Filter for image files
            image_path = os.path.join(image_folder, filename)
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            image = cv2.resize(image, (30, 30))  # Resize the image to 30x30
            
            # Calculate blue score
            blue_score = compute_blue_score(image, blue_range) 
            blue_scores.append(blue_score)
            print(filename)
            print(blue_score)

    plt.hist(blue_scores, bins=20)
    plt.xlabel("Blue Score")
    plt.ylabel("Frequency")
    plt.title("Distribution of Blue Scores")
    plt.show()


# Example usage:
image_folder = "/content/drive/MyDrive/sam/Train3/Lymphocytes"  # Specify the folder containing the images
blue_range = [70, 110, 55, 120, 90, 170]  # Example blue color range in RGB channels

plot_blue_score_distribution(image_folder, blue_range)
# Out:
# img_14_cropped_24.jpg
# 90
# img_14_cropped_7.jpg
# 20
# img_14_cropped_29.jpg
# 84
# img_5_cropped_24.jpg
# 18
# img_5_cropped_26.jpg
# 40
# img_5_cropped_48.jpg
# 179
# img_5_cropped_22.jpg
# 24
# img_5_cropped_43.jpg
# 111
# img_5_cropped_29.jpg
# 21
# img_6_cropped_1.jpg
# 109
# img_147_cropped_27.jpg
# 174
# img_147_cropped_48.jpg
# 215
# img_147_cropped_40.jpg
# 154
# img_147_cropped_35.jpg
# 111
# img_147_cropped_3.jpg
# 39
# img_12_cropped_27.jpg
# 108
# img_12_cropped_35.jpg
# 40
# img_12_cropped_18.jpg
# 48
# img_232_cropped_9.jpg
# 43
# img_232_cropped_14.jpg
# 34
# img_232_cropped_12.jpg
# 54
# img_232_cropped_17.jpg
# 33
# img_3_cropped_7.jpg
# 54
# img_2_cropped_33.jpg
# 70
# img_2_cropped_39.jpg
# 0
# img_2_cropped_16.jpg
# 40

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

def compute_blue_score(image_patch, blue_range):
    total_pixels = np.count_nonzero(np.any(image_patch >= [0, 0, 0], axis=-1))
    blue_pixels = np.count_nonzero(
        (image_patch[:, :, 0] >= blue_range[0]) &
        (image_patch[:, :, 0] <= blue_range[1]) &
        (image_patch[:, :, 1] >= blue_range[2]) &
        (image_patch[:, :, 1] <= blue_range[3]) &
        (image_patch[:, :, 2] >= blue_range[4]) &
        (image_patch[:, :, 2] <= blue_range[5])
    )
    blue_score = blue_pixels
    return blue_score


def plot_blue_score_distribution(image_folder, blue_range):
    blue_scores = []

    for filename in os.listdir(image_folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Filter for image files
            image_path = os.path.join(image_folder, filename)
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            image = cv2.resize(image, (30, 30))  # Resize the image to 30x30
            
            # Calculate blue score
            blue_score = compute_blue_score(image, blue_range) 
            blue_scores.append(blue_score)
            print(filename)
            print(blue_score)

    plt.hist(blue_scores, bins=20)
    plt.xlabel("Blue Score")
    plt.ylabel("Frequency")
    plt.title("Distribution of Blue Scores")
    plt.show()


# Example usage:
image_folder = "/content/drive/MyDrive/sam/Train3/Non-Lymphocytes"  # Specify the folder containing the images
blue_range = [70, 110, 55, 120, 90, 170]  # Example blue color range in RGB channels

plot_blue_score_distribution(image_folder, blue_range)
# Out:
# img_480_cropped_14.jpg
# 1
# img_5_cropped_32.jpg
# 10
# img_5_cropped_40.jpg
# 10
# img_5_cropped_38.jpg
# 1
# img_6_cropped_21.jpg
# 1
# img_6_cropped_5.jpg
# 4
# img_6_cropped_20.jpg
# 21
# img_147_cropped_42.jpg
# 55
# img_12_cropped_22.jpg
# 2
# img_12_cropped_12.jpg
# 6
# img_12_cropped_42.jpg
# 6
# img_12_cropped_57.jpg
# 3
# img_12_cropped_47.jpg
# 1
# img_232_cropped_7.jpg
# 6
# img_232_cropped_19.jpg
# 5
# img_232_cropped_31.jpg
# 3
# img_232_cropped_21.jpg
# 2
# img_241_cropped_31.jpg
# 2
# img_241_cropped_27.jpg
# 5
# img_241_cropped_23.jpg
# 2
# img_241_cropped_7.jpg
# 3
# img_241_cropped_35.jpg
# 0
# img_2_cropped_48.jpg
# 0
# img_2_cropped_60.jpg
# 6

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

def compute_blue_score(image_patch, blue_range):
    total_pixels = np.count_nonzero(np.any(image_patch >= [0, 0, 0], axis=-1))
    blue_pixels = np.count_nonzero(
        (image_patch[:, :, 0] >= blue_range[0]) &
        (image_patch[:, :, 0] <= blue_range[1]) &
        (image_patch[:, :, 1] >= blue_range[2]) &
        (image_patch[:, :, 1] <= blue_range[3]) &
        (image_patch[:, :, 2] >= blue_range[4]) &
        (image_patch[:, :, 2] <= blue_range[5])
    )
    blue_score = blue_pixels
    return blue_score


def plot_blue_score_distribution(image_folder, blue_range):
    blue_scores = []

    for filename in os.listdir(image_folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Filter for image files
            image_path = os.path.join(image_folder, filename)
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            image = cv2.resize(image, (30, 30))  # Resize the image to 30x30
            
            # Calculate blue score
            blue_score = compute_blue_score(image, blue_range) 
            blue_scores.append(blue_score)
            print(filename)
            print(blue_score)

    plt.hist(blue_scores, bins=20)
    plt.xlabel("Blue Score")
    plt.ylabel("Frequency")
    plt.title("Distribution of Blue Scores")
    plt.show()


# Example usage:
image_folder = "/content/drive/MyDrive/sam/Train2/Non-Lymphocytes"  # Specify the folder containing the images
blue_range = [70, 110, 55, 120, 90, 170]  # Example blue color range in RGB channels

plot_blue_score_distribution(image_folder, blue_range)
# Out:
# img_14_cropped_27.jpg
# 243
# img_14_cropped_31.jpg
# 42
# img_14_cropped_17.jpg
# 39
# img_14_cropped_16.jpg
# 47
# img_14_cropped_11.jpg
# 230
# img_14_cropped_30.jpg
# 13
# img_480_cropped_1.jpg
# 8
# img_5_cropped_12.jpg
# 642
# img_5_cropped_4.jpg
# 429
# img_5_cropped_31.jpg
# 199
# img_5_cropped_15.jpg
# 513
# img_5_cropped_28.jpg
# 353
# img_5_cropped_8.jpg
# 321
# img_5_cropped_27.jpg
# 26
# img_5_cropped_1.jpg
# 10
# img_5_cropped_50.jpg
# 157
# img_5_cropped_46.jpg
# 92
# img_5_cropped_0.jpg
# 288
# img_5_cropped_20.jpg
# 73
# img_5_cropped_9.jpg
# 453
# img_5_cropped_18.jpg
# 294
# img_5_cropped_37.jpg
# 478
# img_5_cropped_44.jpg
# 74
# img_5_cropped_35.jpg
# 10
# img_6_cropped_16.jpg
# 3
# img_6_cropped_17.jpg
# 71
# img_6_cropped_8.jpg
# 85
# img_6_cropped_2.jpg
# 296
# img_6_cropped_22.jpg
# 10
# img_147_cropped_11.jpg
# 144
# img_147_cropped_41.jpg
# 515
# img_147_cropped_20.jpg
# 272
# img_147_cropped_21.jpg
# 44
# img_147_cropped_38.jpg
# 328
# ...
